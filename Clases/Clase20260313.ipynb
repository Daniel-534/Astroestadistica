# %% [markdown]
# # Clase Taller

# %% [markdown]
# * Solución del prolema 1 y 3 del taller 2

# %% [markdown]
# * Revisión del taller 3

# %% [markdown]
# **Problema 1, taller 3**

# %%
Integrate[y^3*(1-y/12),{y,0,12}]
# Out:
# 5184
# ----
#  5

# %%
5184/5 * 1/24
# Out:
# 216
# ---
#  5

# %%
12^3/24 * (1/3-1/4)
# Out:
# 6

# %%
216/5-36  //N
# Out:
# 7.2
